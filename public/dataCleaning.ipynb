# %%
import pandas as pd

# %%
df = pd.read_csv("crime_data_with_grid_centers.csv")
df
# Out:
#          IDCol  Report Number    Report Date Day Occurred  Day Number  \
# 0       320197      203581105  12/23/20 0:00    Wednesday           4
# 1       320198      203581144  12/23/20 0:00    Wednesday           4
# 2       320199      203581174  12/23/20 0:00     Saturday           7
# 3       320200      203581238  12/23/20 0:00    Wednesday           4
# 4       320201      203581247  12/23/20 0:00    Wednesday           4
# ...        ...            ...            ...          ...         ...
# 366819  352210       90040607    1/4/09 0:00     Saturday           7
# 366820  352156       90040842    1/4/09 0:00     Saturday           7
# 366821  352157       90040893    1/4/09 0:00       Sunday           1
# 366822  352159       90040901    1/4/09 0:00       Sunday           1
# 366823  352166       90041013    1/4/09 0:00     Saturday           7
#
#        Occur Date Occur Time Possible Date Possible Time  Beat  ...  \
# ...

# %%
len(df)
# Out:
# 366824

# %%
#Count number of distinct Crimes
df.columns
distinct_crime_types = df["Crime Type"].nunique()
print("Distinct Crime Types:", distinct_crime_types)
# Out:
# Distinct Crime Types: 7

# %%
crime_type_names = df["Crime Type"].unique()
print("Names of Distinct Crime Types:")
for crime in crime_type_names:
    print(crime)
# Out:
# Names of Distinct Crime Types:
# BURGLARY
# LARCENY-FROM VEHICLE
# AUTO THEFT
# LARCENY-NON VEHICLE
# AGG ASSAULT
# HOMICIDE
# ROBBERY

# %%
(df['Occur Date'][85])
pd.to_datetime(df['Occur Date'][85])
# Out:
# Timestamp('2020-12-22 00:00:00')

# %%
# df['Occur Date'] = pd.to_datetime(df['Occur Date'], format='%m/%d/%Y')
df['Occur Date'] = pd.to_datetime(df['Occur Date'], errors='coerce')

# %%
df = df.dropna(subset=['Occur Date'])

# %%
df['Year'] = df['Occur Date'].dt.year.astype(int)
# Out:
# /var/folders/h8/bg0mybp576vd322yxr49vszr0000gn/T/ipykernel_30421/3923855561.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Occur Date'].dt.year.astype(int)

# %%
df
# Out:
#          IDCol  Report Number             Report Date Day Occurred  \
# 0       320197      203581105  12/23/2020 12:00:00 AM    Wednesday
# 1       320198      203581144  12/23/2020 12:00:00 AM    Wednesday
# 2       320199      203581174  12/23/2020 12:00:00 AM     Saturday
# 3       320200      203581238  12/23/2020 12:00:00 AM    Wednesday
# 4       320201      203581247  12/23/2020 12:00:00 AM    Wednesday
# ...        ...            ...                     ...          ...
# 366819  352210       90040607    1/4/2009 12:00:00 AM     Saturday
# 366820  352156       90040842    1/4/2009 12:00:00 AM     Saturday
# 366821  352157       90040893    1/4/2009 12:00:00 AM       Sunday
# 366822  352159       90040901    1/4/2009 12:00:00 AM       Sunday
# 366823  352166       90041013    1/4/2009 12:00:00 AM     Saturday
#
#         Day Number Occur Date Occur Time Possible Date Possible Time  Beat  \
# 0                4 2020-12-23      10:00    12/23/2020         16:45   410
# ...

# %%
len(df)
# Out:
# 366816

# %%
df['Year'] = df['Occur Date'].dt.year.astype(int)
# Out:
# /var/folders/h8/bg0mybp576vd322yxr49vszr0000gn/T/ipykernel_30421/2533791419.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Occur Date'].dt.year.astype(int)

# %%
df
# Out:
#          IDCol  Report Number             Report Date Day Occurred  \
# 0       320197      203581105  12/23/2020 12:00:00 AM    Wednesday
# 1       320198      203581144  12/23/2020 12:00:00 AM    Wednesday
# 2       320199      203581174  12/23/2020 12:00:00 AM     Saturday
# 3       320200      203581238  12/23/2020 12:00:00 AM    Wednesday
# 4       320201      203581247  12/23/2020 12:00:00 AM    Wednesday
# ...        ...            ...                     ...          ...
# 366819  352210       90040607    1/4/2009 12:00:00 AM     Saturday
# 366820  352156       90040842    1/4/2009 12:00:00 AM     Saturday
# 366821  352157       90040893    1/4/2009 12:00:00 AM       Sunday
# 366822  352159       90040901    1/4/2009 12:00:00 AM       Sunday
# 366823  352166       90041013    1/4/2009 12:00:00 AM     Saturday
#
#         Day Number Occur Date Occur Time Possible Date Possible Time  Beat  \
# 0                4 2020-12-23      10:00    12/23/2020         16:45   410
# ...

# %%
output_path = "output_data.csv"
df.to_csv(output_path, index=False)

print(f"DataFrame successfully written to {output_path}")
# Out:
# DataFrame successfully written to output_data.csv
